# %% [markdown]
# Carregando o CSV com os dados dos alunos referentes à 2016

# %% [markdown]
# import os
# import pandas as pd
# import numpy as np3
#
# if not os.path.exists("data"):
#     os.mkdir("data")
#     !cd data && curl -O {"http://download.inep.gov.br/microdados/microdados_censo_superior_2016.zip"} && unzip {"'*.zip'"}
#     !cd data/DADOS && unrar e "*.rar" && mv *.CSV ../
#     !cd data && rm -r ANEXOS LEIA-ME DADOS FILTROS && rm microdados_censo_superior_2016.zip

# %% [markdown]
# Coloquei em markdown porque tava demorando pra baixar, já que eu tinha os arquivos aqui... preferi deixar assim por enquanto

# %%
import pandas as pd

#pd.read_csv('data.csv', sep='|
dataframe_alunos_2016 =  pd.read_csv('data/DM_ALUNO.CSV',
                                     sep='|', encoding='latin1',
                                     usecols=['NO_CURSO', 'CO_TURNO_ALUNO', 'CO_GRAU_ACADEMICO', 'CO_ALUNO_CURSO', 'DS_COR_RACA_ALUNO',
                                            'CO_MODALIDADE_ENSINO', 'NO_OCDE', 'DS_SEXO_ALUNO', 'NU_ANO_ALUNO_NASC', 'CO_ALUNO_SITUACAO',
                                             'IN_FINANC_ESTUDANTIL', 'CO_TIPO_ESCOLA_ENS_MEDIO', 'ANO_INGRESSO'])
dataframe_alunos_2016.head()
# Out:
#   NO_CURSO  CO_TURNO_ALUNO  CO_GRAU_ACADEMICO  CO_MODALIDADE_ENSINO  NO_OCDE  \
# 0  DIREITO             3.0                1.0                     1  Direito
# 1  DIREITO             3.0                1.0                     1  Direito
# 2  DIREITO             3.0                1.0                     1  Direito
# 3  DIREITO             3.0                1.0                     1  Direito
# 4  DIREITO             1.0                1.0                     1  Direito
#
#    CO_ALUNO_CURSO DS_COR_RACA_ALUNO DS_SEXO_ALUNO  NU_ANO_ALUNO_NASC  \
# 0        25001314             Parda     Masculino               1987
# 1        25037243             Parda     Masculino               1988
# 2        25030916             Preta      Feminino               1988
# 3        25016919             Parda     Masculino               1977
# 4        25001942             Parda     Masculino               1983
#
#    CO_ALUNO_SITUACAO  IN_FINANC_ESTUDANTIL  CO_TIPO_ESCOLA_ENS_MEDIO  \
# 0                  2                   NaN                         1
# 1                  2                   NaN                         1
# 2                  3                   NaN                         1
# 3                  3                   NaN                         1
# 4                  4                   NaN                         1
#
#    ANO_INGRESSO
# 0          2016
# 1          2012
# 2          2015
# 3          2013
# 4          2011

# %%
print(dataframe_alunos_2016.groupby('IN_FINANC_ESTUDANTIL').count())
# Out:
#                       NO_CURSO  CO_TURNO_ALUNO  CO_GRAU_ACADEMICO  \
# IN_FINANC_ESTUDANTIL
# 0.0                    5861875         4200346            5854134
# 1.0                    3355160         2829900            3354427
#
#                       CO_MODALIDADE_ENSINO  NO_OCDE  CO_ALUNO_CURSO  \
# IN_FINANC_ESTUDANTIL
# 0.0                                5861875  5861552         5861875
# 1.0                                3355160  3355044         3355160
#
#                       DS_COR_RACA_ALUNO  DS_SEXO_ALUNO  NU_ANO_ALUNO_NASC  \
# IN_FINANC_ESTUDANTIL
# 0.0                             5861875        5861875            5861875
# 1.0                             3355160        3355160            3355160
#
#                       CO_ALUNO_SITUACAO  CO_TIPO_ESCOLA_ENS_MEDIO  \
# IN_FINANC_ESTUDANTIL
# 0.0                             5861875                   5861875
# 1.0                             3355160                   3355160
#
#                       ANO_INGRESSO
# IN_FINANC_ESTUDANTIL
# 0.0                        5861875
# 1.0                        3355160

# %%
dataframe_alunos_2016.to_csv('data/alunos2016.csv')

# %%
DF_alunos2016 =  pd.read_csv('data/alunos2016.csv')
DF_alunos2016.head()
# Out:
#    Unnamed: 0 NO_CURSO  CO_TURNO_ALUNO  CO_GRAU_ACADEMICO  \
# 0           0  DIREITO             3.0                1.0
# 1           1  DIREITO             3.0                1.0
# 2           2  DIREITO             3.0                1.0
# 3           3  DIREITO             3.0                1.0
# 4           4  DIREITO             1.0                1.0
#
#    CO_MODALIDADE_ENSINO  NO_OCDE  CO_ALUNO_CURSO DS_COR_RACA_ALUNO  \
# 0                     1  Direito        25001314             Parda
# 1                     1  Direito        25037243             Parda
# 2                     1  Direito        25030916             Preta
# 3                     1  Direito        25016919             Parda
# 4                     1  Direito        25001942             Parda
#
#   DS_SEXO_ALUNO  NU_ANO_ALUNO_NASC  CO_ALUNO_SITUACAO  IN_FINANC_ESTUDANTIL  \
# 0     Masculino               1987                  2                   NaN
# 1     Masculino               1988                  2                   NaN
# 2      Feminino               1988                  3                   NaN
# 3     Masculino               1977                  3                   NaN
# 4     Masculino               1983                  4                   NaN
#
#    CO_TIPO_ESCOLA_ENS_MEDIO  ANO_INGRESSO
# 0                         1          2016
# 1                         1          2012
# 2                         1          2015
# 3                         1          2013
# 4                         1          2011

# %%
qtd_cursos = len(DF_alunos2016.NO_OCDE.drop_duplicates())
qtd_cursos
# Out:
# 350

# %%
curso_raca = DF_alunos2016
curso_raca = pd.melt(curso_raca, id_vars = 'NO_OCDE', value_vars ='DS_COR_RACA_ALUNO')

curso_raca.head()
# Out:
#    NO_OCDE           variable  value
# 0  Direito  DS_COR_RACA_ALUNO  Parda
# 1  Direito  DS_COR_RACA_ALUNO  Parda
# 2  Direito  DS_COR_RACA_ALUNO  Preta
# 3  Direito  DS_COR_RACA_ALUNO  Parda
# 4  Direito  DS_COR_RACA_ALUNO  Parda

# %%
curso_raca = curso_raca.rename(columns= {'value' : 'raca'})
curso_raca = curso_raca.rename(columns= {'NO_OCDE' : 'curso'})
curso_raca = curso_raca.rename(columns= {'variable' : 'qtd'})

curso_raca = curso_raca.replace(to_replace = 'DS_COR_RACA_ALUNO', value = 1)

curso_raca = curso_raca.pivot_table(index = 'curso', columns='raca', values= 'qtd',aggfunc='sum')

curso_raca.head()
# Out:
# raca                                      Aluno não quis declarar cor/raça  \
# curso
# Acústica                                                               4.0
# Administração                                                     345790.0
# Administração de cooperativas                                        398.0
# Administração de redes                                             11294.0
# Administração de sistemas de informações                               NaN
#
# raca                                      Amarela    Branca  Indígena  \
# curso
# Acústica                                      NaN     187.0       NaN
# Administração                             15172.0  393559.0    4783.0
# Administração de cooperativas                17.0     597.0       6.0
# Administração de redes                      575.0   11277.0     198.0
# Administração de sistemas de informações      NaN       NaN       NaN
#
# raca                                      Não dispõe da informação     Parda  \
# curso
# Acústica                                                       NaN      19.0
# Administração                                              34924.0  244571.0
# Administração de cooperativas                                  6.0     382.0
# Administração de redes                                       924.0    8918.0
# Administração de sistemas de informações                       NaN       6.0
#
# raca                                        Preta
# curso
# Acústica                                     10.0
# Administração                             54294.0
# Administração de cooperativas               156.0
# Administração de redes                     2618.0
# Administração de sistemas de informações      NaN

# %%
curso_raca.loc['Administração']
# Out:
# raca
# Aluno não quis declarar cor/raça    345790.0
# Amarela                              15172.0
# Branca                              393559.0
# Indígena                              4783.0
# Não dispõe da informação             34924.0
# Parda                               244571.0
# Preta                                54294.0
# Name: Administração, dtype: float64

# %% [markdown]
# Com isso, podemos selecionar relações entre os cursos e as raças

# %%
for i in range(0,6):
    print(curso_raca.iloc[:,i].idxmax())
# Out:
# Administração
# Direito
# Direito
# Direito
# Administração
# Direito

# %% [markdown]
# Pegando o curso com maior qtd por coluna

# %%
curso_raca.iloc[:].nlargest(5,'Amarela')
# Out:
# raca                Aluno não quis declarar cor/raça  Amarela    Branca  \
# curso
# Direito                                     311136.0  17151.0  456318.0
# Administração                               345790.0  15172.0  393559.0
# Pedagogia                                   293977.0  10045.0  293059.0
# Engenharia civil                            135277.0   9478.0  202143.0
# Ciências contábeis                          163908.0   7583.0  174480.0
#
# raca                Indígena  Não dispõe da informação     Parda    Preta
# curso
# Direito               6425.0                   23740.0  257764.0  62355.0
# Administração         4783.0                   34924.0  244571.0  54294.0
# Pedagogia             5789.0                   33826.0  220415.0  53091.0
# Engenharia civil      3574.0                    7798.0  111778.0  25950.0
# Ciências contábeis    2634.0                   11614.0  126821.0  27837.0

# %% [markdown]
# Dessa forma mostra os n maiores cursos por raça, mas "ordena" pela coluna selecionada, nesse caso, foi "Amarela"
